# %%
# !pip install ark_nlp
# Out:
# Collecting ark_nlp
#   Downloading ark-nlp-0.0.9.tar.gz (78 kB)
#      |████████████████████████████████| 78 kB 2.7 kB/s eta 0:00:03
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ark_nlp) (1.11.0)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.7/dist-packages (from ark_nlp) (4.64.0)
# Requirement already satisfied: jieba>=0.42.1 in /usr/local/lib/python3.7/dist-packages (from ark_nlp) (0.42.1)
# Requirement already satisfied: transformers>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from ark_nlp) (4.19.2)
# Collecting zhon>=1.1.5
#   Downloading zhon-1.1.5.tar.gz (99 kB)
#      |████████████████████████████████| 99 kB 3.8 kB/s eta 0:00:02
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from ark_nlp) (1.7.3)
# Requirement already satisfied: scikit-learn>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from ark_nlp) (1.0.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.0.0->ark_nlp) (4.0.1)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers>=3.0.0->ark_nlp) (4.10.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers>=3.0.0->ark_nlp) (0.5.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers>=3.0.0->ark_nlp) (2022.4.24)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers>=3.0.0->ark_nlp) (0.12.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers>=3.0.0->ark_nlp) (6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers>=3.0.0->ark_nlp) (21.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers>=3.0.0->ark_nlp) (2.27.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers>=3.0.0->ark_nlp) (3.4.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers>=3.0.0->ark_nlp) (1.21.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.17.0->ark_nlp) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.17.0->ark_nlp) (3.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers>=3.0.0->ark_nlp) (3.7.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers>=3.0.0->ark_nlp) (3.0.6)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in /usr/local/lib/python3.7/dist-packages (from requests->transformers>=3.0.0->ark_nlp) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in /usr/local/lib/python3.7/dist-packages (from requests->transformers>=3.0.0->ark_nlp) (2.0.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers>=3.0.0->ark_nlp) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers>=3.0.0->ark_nlp) (2021.10.8)
# Building wheels for collected packages: ark-nlp, zhon
#   Building wheel for ark-nlp (setup.py) ... done
#   Created wheel for ark-nlp: filename=ark_nlp-0.0.9-py3-none-any.whl size=174427 sha256=35880c32e3563dde7380ace8391926dafaf057a0cacb5b0651801f1ce8cf1509
#   Stored in directory: /root/.cache/pip/wheels/63/4c/22/b3283dcd140244b3e8527bbd2769ea9b06ac4e5d0ddeaf4381
#   Building wheel for zhon (setup.py) ... done
#   Created wheel for zhon: filename=zhon-1.1.5-py3-none-any.whl size=84292 sha256=b539b80f7d7b0e53332cd40450c7332a27810410a4ecf0523420e1b1c4a0bc5e
#   Stored in directory: /root/.cache/pip/wheels/d0/56/17/2675c4c7413a72bf173062e8d0a16503e3b2607745aa84988d
# Successfully built ark-nlp zhon
# Installing collected packages: zhon, ark-nlp
# Successfully installed ark-nlp-0.0.9 zhon-1.1.5

# %%
import warnings
warnings.filterwarnings("ignore")

import os
import json
import jieba
import torch
import pickle
import codecs
import torch.nn as nn
import torch.optim as optim
import pandas as pd

from ark_nlp.model.re.casrel_bert import CasRelBert
from ark_nlp.model.re.casrel_bert import CasRelBertConfig
from ark_nlp.model.re.casrel_bert import Dataset
from ark_nlp.model.re.casrel_bert import Task
from ark_nlp.model.re.casrel_bert import get_default_model_optimizer
from ark_nlp.model.re.casrel_bert import Tokenizer
from ark_nlp.factory.loss_function import CasRelLoss

# %%
# 目录地址

train_data_path = '../mydata/data_origin/220602_0902-cblue-nlp-医疗nlp打榜/CMeIE/CMeIE_train.jsonl'
dev_data_path = '../mydata/data_origin/220602_0902-cblue-nlp-医疗nlp打榜/CMeIE/CMeIE_dev.jsonl'

# %% [markdown]
# #### 1. 数据读入

# %%
train_data_list = []

with codecs.open(train_data_path, mode='r', encoding='utf8') as f:
    lines = f.readlines()
    for index_, line_ in enumerate(lines):
        record_ = {}
        line_ = json.loads(line_.strip())
        record_['text'] = line_['text']
        record_['label'] = []
        for triple_ in line_['spo_list']:
            record_['label'].append([
                triple_['subject'],
                record_['text'].index(triple_['subject']),
                record_['text'].index(triple_['subject'])+ len(triple_['subject']) - 1,
                triple_['predicate'] + '@' + triple_['object_type']['@value'],
                triple_['object']['@value'],
                record_['text'].index(triple_['object']['@value']),
                record_['text'].index(triple_['object']['@value']) + len(triple_['object']['@value']) - 1,
            ])
        train_data_list.append(record_)

train_df = pd.DataFrame(train_data_list)

# %%
dev_data_list = []
counter = 0
with codecs.open(dev_data_path, mode='r', encoding='utf8') as f:
    lines = f.readlines()
    for index_, line_ in enumerate(lines):
        record_ = {}
        line_ = json.loads(line_.strip())
        record_['text'] = line_['text']
        record_['label'] = []
        for triple_ in line_['spo_list']:
            record_['label'].append([
                triple_['subject'],
                record_['text'].index(triple_['subject']),
                record_['text'].index(triple_['subject'])+ len(triple_['subject']) - 1,
                triple_['predicate'] + '@' + triple_['object_type']['@value'],
                triple_['object']['@value'],
                record_['text'].index(triple_['object']['@value']),
                record_['text'].index(triple_['object']['@value']) + len(triple_['object']['@value']) - 1,
            ])
            counter += 1
        dev_data_list.append(record_)
        
dev_df = pd.DataFrame(dev_data_list)

# %%
re_train_dataset = Dataset(train_df)
re_dev_dataset = Dataset(dev_df,
                         categories = re_train_dataset.categories,
                         is_train=False)

# %% [markdown]
# #### 2. 词典创建和生成分词器

# %%
tokenizer = Tokenizer(
    vocab='nghuyong/ernie-1.0',
    max_seq_len=128
)
# Out:
# Downloading:   0%|          | 0.00/62.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/420 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/89.0k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %% [markdown]
# #### 3. ID化

# %%
re_train_dataset.convert_to_ids(tokenizer)
re_dev_dataset.convert_to_ids(tokenizer)

# %% [markdown]
# <br>
#
# ### 二、模型构建

# %% [markdown]
# #### 1. 模型参数设置

# %%
bert_config = CasRelBertConfig.from_pretrained('nghuyong/ernie-1.0',
                                               num_labels=len(re_train_dataset.cat2id))

# %% [markdown]
# #### 2. 模型创建

# %%
dl_module = CasRelBert.from_pretrained('nghuyong/ernie-1.0',
                                       config=bert_config)
# Out:
# Downloading:   0%|          | 0.00/383M [00:00<?, ?B/s]
# Some weights of the model checkpoint at nghuyong/ernie-1.0 were not used when initializing CasRelBert: ['cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.predictions.decoder.bias', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing CasRelBert from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing CasRelBert from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of CasRelBert were not initialized from the model checkpoint at nghuyong/ernie-1.0 and are newly initialized: ['obj_heads_linear.weight', 'sub_heads_linear.weight', 'obj_tails_linear.weight', 'sub_heads_linear.bias', 'obj_heads_linear.bias', 'obj_tails_linear.bias', 'sub_tails_linear.weight', 'sub_tails_linear.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# <br>
#
# ### 三、任务构建

# %% [markdown]
# #### 1. 任务参数和必要部件设定

# %%
optimizer = get_default_model_optimizer(dl_module)

# %% [markdown]
# #### 2. 任务创建

# %%
model = Task(dl_module, optimizer, CasRelLoss(), cuda_device=1)

# %% [markdown]
# #### 3. 训练

# %%
model.fit(
    re_train_dataset,
    re_dev_dataset,
    lr=4e-5,
    epochs=20,
    batch_size=16
)
# Out:
# [99/897],train loss is:10.906454
# [199/897],train loss is:6.213885
# [299/897],train loss is:4.473707
# [399/897],train loss is:3.559849
# [499/897],train loss is:2.998150
# [599/897],train loss is:2.614500
# [699/897],train loss is:2.337759
# [799/897],train loss is:2.126076
# epoch:[0],train loss is:1.965480
#
# pred_triples:  set()
# gold_triples:  {('急性胰腺炎', '影像学检查@检查', 'ERCP')}
# pred_triples:  set()
# gold_triples:  {('广泛性焦虑症', '鉴别诊断@疾病', '社交性焦虑'), ('广泛性焦虑症', '鉴别诊断@疾病', '分离性焦虑')}
# pred_triples:  set()
# gold_triples:  {('骨性关节炎', '发病部位@部位', '关节'), ('骨性关节炎', '发病部位@部位', '踝关节'), ('骨性关节炎', '病因@社会学', '创伤'), ('骨性关节炎', '发病部位@部位', '腕关节'), ('骨性关节炎', '病因@社会学', '结晶性关节病')}
# pred_triples:  set()
# gold_triples:  {('胆囊穿孔', '死亡率@流行病学', '30%')}
# pred_triples:  set()
# gold_triples:  {('乙型肝炎', '预防@其他', '不献血'), ('乙型肝炎', '预防@其他', '不捐献器官或精液')}
# pred_triples:  set()
# gold_triples:  {('心绞痛', '药物治疗@药物', 'β受体阻滞剂')}
# pred_triples:  set()
# gold_triples:  {('感染性心内膜炎', '病因@社会学', '链球菌')}
# pred_triples:  set()
# gold_triples:  {('稳定型缺血性心脏疾病', '药物治疗@药物', '高强度他汀类药物治疗')}
# pred_triples:  set()
# gold_triples:  {('营养性巨幼细胞性贫血', '病因@社会学', '维生素B12和（或）叶酸缺乏'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '维生素B12'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '叶酸'), ('营养性巨幼细胞性贫血', '同义词@疾病', 'nutritional megaloblastic anemia')}
# pred_triples:  set()
# gold_triples:  {('原发性高血压', '预防@其他', '适量的咖啡因摄入量')}
# correct_num:   0, predict_num:   0, gold_num: 10613
# precision: 0.0, recall: 0.0, f1_score: 0.0
# [99/897],train loss is:0.618246
# [199/897],train loss is:0.598721
# [299/897],train loss is:0.569637
# [399/897],train loss is:0.544893
# [499/897],train loss is:0.523467
# [599/897],train loss is:0.502548
# [699/897],train loss is:0.484290
# [799/897],train loss is:0.467889
# epoch:[1],train loss is:0.452951
#
# pred_triples:  set()
# gold_triples:  {('急性胰腺炎', '影像学检查@检查', 'ERCP')}
# pred_triples:  set()
# gold_triples:  {('广泛性焦虑症', '鉴别诊断@疾病', '社交性焦虑'), ('广泛性焦虑症', '鉴别诊断@疾病', '分离性焦虑')}
# pred_triples:  set()
# gold_triples:  {('骨性关节炎', '发病部位@部位', '关节'), ('骨性关节炎', '发病部位@部位', '踝关节'), ('骨性关节炎', '病因@社会学', '创伤'), ('骨性关节炎', '发病部位@部位', '腕关节'), ('骨性关节炎', '病因@社会学', '结晶性关节病')}
# pred_triples:  set()
# gold_triples:  {('胆囊穿孔', '死亡率@流行病学', '30%')}
# pred_triples:  set()
# gold_triples:  {('乙型肝炎', '预防@其他', '不献血'), ('乙型肝炎', '预防@其他', '不捐献器官或精液')}
# pred_triples:  {('心肌梗死', '药物治疗@药物', '受体阻滞剂'), ('稳定型缺血性心脏疾病', '药物治疗@药物', '受体阻滞剂')}
# gold_triples:  {('心绞痛', '药物治疗@药物', 'β受体阻滞剂')}
# pred_triples:  set()
# gold_triples:  {('感染性心内膜炎', '病因@社会学', '链球菌')}
# pred_triples:  {('稳定型缺血性心脏疾病', '药物治疗@药物', '高强度他汀类药物')}
# gold_triples:  {('稳定型缺血性心脏疾病', '药物治疗@药物', '高强度他汀类药物治疗')}
# pred_triples:  {('营养性巨幼细胞性贫血', '同义词@疾病', 'nutritional megaloblastic anemia')}
# gold_triples:  {('营养性巨幼细胞性贫血', '病因@社会学', '维生素B12和（或）叶酸缺乏'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '维生素B12'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '叶酸'), ('营养性巨幼细胞性贫血', '同义词@疾病', 'nutritional megaloblastic anemia')}
# pred_triples:  {('原发性高血压', '药物治疗@药物', '咖啡因')}
# gold_triples:  {('原发性高血压', '预防@其他', '适量的咖啡因摄入量')}
# correct_num: 2186, predict_num: 5320, gold_num: 10613
# precision: 0.41090225563909, recall: 0.2059738057099764, f1_score: 0.27439904596066106
# [99/897],train loss is:0.306891
# [199/897],train loss is:0.301781
# [299/897],train loss is:0.294321
# [399/897],train loss is:0.290515
# [499/897],train loss is:0.285396
# [599/897],train loss is:0.281862
# [699/897],train loss is:0.276666
# [799/897],train loss is:0.273366
# epoch:[2],train loss is:0.270228
#
# pred_triples:  {('梗阻性胆总管结石', '影像学检查@检查', 'ERCP'), ('急性胰腺炎', '影像学检查@检查', 'ERCP')}
# gold_triples:  {('急性胰腺炎', '影像学检查@检查', 'ERCP')}
# pred_triples:  set()
# gold_triples:  {('广泛性焦虑症', '鉴别诊断@疾病', '社交性焦虑'), ('广泛性焦虑症', '鉴别诊断@疾病', '分离性焦虑')}
# pred_triples:  {('骨性关节炎', '病因@社会学', '创伤')}
# gold_triples:  {('骨性关节炎', '发病部位@部位', '关节'), ('骨性关节炎', '发病部位@部位', '踝关节'), ('骨性关节炎', '病因@社会学', '创伤'), ('骨性关节炎', '发病部位@部位', '腕关节'), ('骨性关节炎', '病因@社会学', '结晶性关节病')}
# pred_triples:  set()
# gold_triples:  {('胆囊穿孔', '死亡率@流行病学', '30%')}
# pred_triples:  set()
# gold_triples:  {('乙型肝炎', '预防@其他', '不献血'), ('乙型肝炎', '预防@其他', '不捐献器官或精液')}
# pred_triples:  set()
# gold_triples:  {('心绞痛', '药物治疗@药物', 'β受体阻滞剂')}
# pred_triples:  {('感染性心内膜炎', '病因@社会学', '葡萄球菌'), ('感染性心内膜炎', '病因@社会学', '链球菌')}
# gold_triples:  {('感染性心内膜炎', '病因@社会学', '链球菌')}
# pred_triples:  set()
# gold_triples:  {('稳定型缺血性心脏疾病', '药物治疗@药物', '高强度他汀类药物治疗')}
# pred_triples:  {('营养性巨幼细胞性贫血', '病因@社会学', '维生素B12'), ('营养性巨幼细胞性贫血', '同义词@疾病', 'nutritional megaloblastic anemia')}
# gold_triples:  {('营养性巨幼细胞性贫血', '病因@社会学', '维生素B12和（或）叶酸缺乏'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '维生素B12'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '叶酸'), ('营养性巨幼细胞性贫血', '同义词@疾病', 'nutritional megaloblastic anemia')}
# pred_triples:  set()
# gold_triples:  {('原发性高血压', '预防@其他', '适量的咖啡因摄入量')}
# correct_num: 3128, predict_num: 6437, gold_num: 10613
# precision: 0.48594065558489224, recall: 0.29473287477621507, f1_score: 0.3669208210673647
# [99/897],train loss is:0.226521
# [199/897],train loss is:0.222913
# [299/897],train loss is:0.221138
# [399/897],train loss is:0.217397
# [499/897],train loss is:0.216692
# [599/897],train loss is:0.215503
# [699/897],train loss is:0.212660
# [799/897],train loss is:0.211407
# epoch:[3],train loss is:0.210720
#
# pred_triples:  {('梗阻性胆总管结石', '影像学检查@检查', 'ERCP')}
# gold_triples:  {('急性胰腺炎', '影像学检查@检查', 'ERCP')}
# pred_triples:  set()
# gold_triples:  {('广泛性焦虑症', '鉴别诊断@疾病', '社交性焦虑'), ('广泛性焦虑症', '鉴别诊断@疾病', '分离性焦虑')}
# pred_triples:  {('骨性关节炎', '病因@社会学', '创伤'), ('骨性关节炎', '发病部位@部位', '腕关节'), ('骨性关节炎', '发病部位@部位', '踝关节')}
# gold_triples:  {('骨性关节炎', '发病部位@部位', '关节'), ('骨性关节炎', '发病部位@部位', '踝关节'), ('骨性关节炎', '病因@社会学', '创伤'), ('骨性关节炎', '发病部位@部位', '腕关节'), ('骨性关节炎', '病因@社会学', '结晶性关节病')}
# pred_triples:  set()
# gold_triples:  {('胆囊穿孔', '死亡率@流行病学', '30%')}
# pred_triples:  set()
# gold_triples:  {('乙型肝炎', '预防@其他', '不献血'), ('乙型肝炎', '预防@其他', '不捐献器官或精液')}
# pred_triples:  set()
# gold_triples:  {('心绞痛', '药物治疗@药物', 'β受体阻滞剂')}
# pred_triples:  set()
# gold_triples:  {('感染性心内膜炎', '病因@社会学', '链球菌')}
# pred_triples:  {('稳定型缺血性心脏疾病', '药物治疗@药物', '高强度他汀类药物治疗')}
# gold_triples:  {('稳定型缺血性心脏疾病', '药物治疗@药物', '高强度他汀类药物治疗')}
# pred_triples:  {('营养性巨幼细胞性贫血', '病因@社会学', '维生素B12和（或）叶酸缺乏'), ('营养性巨幼细胞性贫血', '同义词@疾病', 'nutritional megaloblastic anemia')}
# gold_triples:  {('营养性巨幼细胞性贫血', '病因@社会学', '维生素B12和（或）叶酸缺乏'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '维生素B12'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '叶酸'), ('营养性巨幼细胞性贫血', '同义词@疾病', 'nutritional megaloblastic anemia')}
# pred_triples:  set()
# gold_triples:  {('原发性高血压', '预防@其他', '适量的咖啡因摄入量')}
# correct_num: 3479, predict_num: 6221, gold_num: 10613
# precision: 0.5592348497026112, recall: 0.3278055215301957, f1_score: 0.4133301650953731
# [99/897],train loss is:0.174918
# [199/897],train loss is:0.176540
# [299/897],train loss is:0.179172
# [399/897],train loss is:0.180217
# [499/897],train loss is:0.179945
# [599/897],train loss is:0.178878
# [699/897],train loss is:0.178092
# [799/897],train loss is:0.177277
# epoch:[4],train loss is:0.176496
#
# pred_triples:  set()
# gold_triples:  {('急性胰腺炎', '影像学检查@检查', 'ERCP')}
# pred_triples:  set()
# gold_triples:  {('广泛性焦虑症', '鉴别诊断@疾病', '社交性焦虑'), ('广泛性焦虑症', '鉴别诊断@疾病', '分离性焦虑')}
# pred_triples:  {('骨性关节炎', '发病部位@部位', '腕关节'), ('骨性关节炎', '发病部位@部位', '踝关节')}
# gold_triples:  {('骨性关节炎', '发病部位@部位', '关节'), ('骨性关节炎', '发病部位@部位', '踝关节'), ('骨性关节炎', '病因@社会学', '创伤'), ('骨性关节炎', '发病部位@部位', '腕关节'), ('骨性关节炎', '病因@社会学', '结晶性关节病')}
# pred_triples:  set()
# gold_triples:  {('胆囊穿孔', '死亡率@流行病学', '30%')}
# pred_triples:  set()
# gold_triples:  {('乙型肝炎', '预防@其他', '不献血'), ('乙型肝炎', '预防@其他', '不捐献器官或精液')}
# pred_triples:  set()
# gold_triples:  {('心绞痛', '药物治疗@药物', 'β受体阻滞剂')}
# pred_triples:  set()
# gold_triples:  {('感染性心内膜炎', '病因@社会学', '链球菌')}
# pred_triples:  set()
# gold_triples:  {('稳定型缺血性心脏疾病', '药物治疗@药物', '高强度他汀类药物治疗')}
# pred_triples:  {('营养性巨幼细胞性贫血', '病因@社会学', '维生素B12和（或）叶酸缺乏'), ('营养性巨幼细胞性贫血', '同义词@疾病', 'nutritional megaloblastic anemia')}
# gold_triples:  {('营养性巨幼细胞性贫血', '病因@社会学', '维生素B12和（或）叶酸缺乏'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '维生素B12'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '叶酸'), ('营养性巨幼细胞性贫血', '同义词@疾病', 'nutritional megaloblastic anemia')}
# pred_triples:  set()
# gold_triples:  {('原发性高血压', '预防@其他', '适量的咖啡因摄入量')}
# correct_num: 3453, predict_num: 5653, gold_num: 10613
# precision: 0.6108261100300617, recall: 0.3253556958447157, f1_score: 0.4245665805522094
# [99/897],train loss is:0.153800
# [199/897],train loss is:0.154296
# [299/897],train loss is:0.154159
# [399/897],train loss is:0.152711
# [499/897],train loss is:0.152979
# [599/897],train loss is:0.152538
# [699/897],train loss is:0.151763
# [799/897],train loss is:0.151825
# epoch:[5],train loss is:0.151835
#
# pred_triples:  {('梗阻性胆总管结石', '影像学检查@检查', 'ERCP'), ('胆汁性急性胰腺炎', '影像学检查@检查', 'ERCP')}
# gold_triples:  {('急性胰腺炎', '影像学检查@检查', 'ERCP')}
# pred_triples:  {('焦虑情绪', '临床表现@症状', '躯体不适症状')}
# gold_triples:  {('广泛性焦虑症', '鉴别诊断@疾病', '社交性焦虑'), ('广泛性焦虑症', '鉴别诊断@疾病', '分离性焦虑')}
# pred_triples:  {('骨性关节炎', '发病部位@部位', '踝关节'), ('骨性关节炎', '病因@社会学', '创伤'), ('骨性关节炎', '发病部位@部位', '腕关节'), ('骨性关节炎', '发病部位@部位', '关节炎@在其他关节（如踝关节'), ('骨性关节炎', '病因@社会学', '结晶性关节病')}
# gold_triples:  {('骨性关节炎', '发病部位@部位', '关节'), ('骨性关节炎', '发病部位@部位', '踝关节'), ('骨性关节炎', '病因@社会学', '创伤'), ('骨性关节炎', '发病部位@部位', '腕关节'), ('骨性关节炎', '病因@社会学', '结晶性关节病')}
# pred_triples:  set()
# gold_triples:  {('胆囊穿孔', '死亡率@流行病学', '30%')}
# pred_triples:  set()
# gold_triples:  {('乙型肝炎', '预防@其他', '不献血'), ('乙型肝炎', '预防@其他', '不捐献器官或精液')}
# pred_triples:  {('抗心绞痛', '药物治疗@药物', 'β受体阻滞剂'), ('抗心绞痛', '药物治疗@药物', '抗心绞痛药物 * 抗心绞痛药物的主要目标是减少心绞痛症状，改善生活质量。稳定型缺血性心脏疾病@ * β受体阻滞剂')}
# gold_triples:  {('心绞痛', '药物治疗@药物', 'β受体阻滞剂')}
# pred_triples:  set()
# gold_triples:  {('感染性心内膜炎', '病因@社会学', '链球菌')}
# pred_triples:  {('稳定型缺血性心脏疾病', '药物治疗@药物', '高强度他汀类药物治疗')}
# gold_triples:  {('稳定型缺血性心脏疾病', '药物治疗@药物', '高强度他汀类药物治疗')}
# pred_triples:  {('营养性巨幼细胞性贫血', '药物治疗@药物', '维生素Bl2治疗'), ('营养性巨幼细胞性贫血', '病因@社会学', '维生素B12'), ('营养性巨幼细胞性贫血', '同义词@疾病', 'nutritional megaloblastic anemia'), ('营养性巨幼细胞性贫血', '病因@社会学', '叶酸缺乏')}
# gold_triples:  {('营养性巨幼细胞性贫血', '病因@社会学', '维生素B12和（或）叶酸缺乏'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '维生素B12'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '叶酸'), ('营养性巨幼细胞性贫血', '同义词@疾病', 'nutritional megaloblastic anemia')}
# pred_triples:  set()
# gold_triples:  {('原发性高血压', '预防@其他', '适量的咖啡因摄入量')}
# correct_num: 4428, predict_num: 8759, gold_num: 10613
# precision: 0.5055371617764527, recall: 0.4172241590502175, f1_score: 0.45715465615528494
# [99/897],train loss is:0.130584
# [199/897],train loss is:0.129650
# [299/897],train loss is:0.131838
# [399/897],train loss is:0.132452
# [499/897],train loss is:0.132256
# [599/897],train loss is:0.131978
# [699/897],train loss is:0.131481
# [799/897],train loss is:0.131093
# epoch:[6],train loss is:0.131084
#
# pred_triples:  {('梗阻性胆总管结石', '影像学检查@检查', 'ERCP')}
# gold_triples:  {('急性胰腺炎', '影像学检查@检查', 'ERCP')}
# pred_triples:  set()
# gold_triples:  {('广泛性焦虑症', '鉴别诊断@疾病', '社交性焦虑'), ('广泛性焦虑症', '鉴别诊断@疾病', '分离性焦虑')}
# pred_triples:  {('骨性关节炎', '发病部位@部位', '关节炎@在其他关节（如踝关节'), ('结晶性关节病', '病因@社会学', '创伤'), ('骨性关节炎', '发病部位@部位', '腕关节'), ('骨性关节炎', '发病部位@部位', '踝关节')}
# gold_triples:  {('骨性关节炎', '发病部位@部位', '关节'), ('骨性关节炎', '发病部位@部位', '踝关节'), ('骨性关节炎', '病因@社会学', '创伤'), ('骨性关节炎', '发病部位@部位', '腕关节'), ('骨性关节炎', '病因@社会学', '结晶性关节病')}
# pred_triples:  set()
# gold_triples:  {('胆囊穿孔', '死亡率@流行病学', '30%')}
# pred_triples:  {('乙型肝炎', '预防@其他', '使用漂白剂或洗涤剂清洁溢出血液，不献血'), ('乙型肝炎', '预防@其他', '不献血'), ('乙型肝炎', '预防@其他', '遮盖开放的割伤和擦伤，使用漂白剂或洗涤剂清洁溢出血液，不献血'), ('乙型肝炎', '预防@其他', '不捐献器官或精液')}
# gold_triples:  {('乙型肝炎', '预防@其他', '不献血'), ('乙型肝炎', '预防@其他', '不捐献器官或精液')}
# pred_triples:  set()
# gold_triples:  {('心绞痛', '药物治疗@药物', 'β受体阻滞剂')}
# pred_triples:  set()
# gold_triples:  {('感染性心内膜炎', '病因@社会学', '链球菌')}
# pred_triples:  {('稳定型缺血性心脏疾病', '药物治疗@药物', '高强度他汀类药物治疗')}
# gold_triples:  {('稳定型缺血性心脏疾病', '药物治疗@药物', '高强度他汀类药物治疗')}
# pred_triples:  {('营养性巨幼细胞性贫血', '药物治疗@药物', '维生素Bl2治疗'), ('营养性巨幼细胞性贫血', '病因@社会学', '维生素B12'), ('营养性巨幼细胞性贫血', '同义词@疾病', 'nutritional megaloblastic anemia')}
# gold_triples:  {('营养性巨幼细胞性贫血', '病因@社会学', '维生素B12和（或）叶酸缺乏'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '维生素B12'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '叶酸'), ('营养性巨幼细胞性贫血', '同义词@疾病', 'nutritional megaloblastic anemia')}
# pred_triples:  set()
# gold_triples:  {('原发性高血压', '预防@其他', '适量的咖啡因摄入量')}
# correct_num: 4489, predict_num: 8164, gold_num: 10613
# precision: 0.5498530132288026, recall: 0.422971827004613, f1_score: 0.47813814768477525
# [99/897],train loss is:0.115000
# [199/897],train loss is:0.114089
# [299/897],train loss is:0.114779
# [399/897],train loss is:0.115752
# [499/897],train loss is:0.116388
# [599/897],train loss is:0.116941
# [699/897],train loss is:0.117063
# [799/897],train loss is:0.116584
# epoch:[7],train loss is:0.117041
#
# pred_triples:  {('梗阻性胆总管结石', '影像学检查@检查', 'ERCP')}
# gold_triples:  {('急性胰腺炎', '影像学检查@检查', 'ERCP')}
# pred_triples:  set()
# gold_triples:  {('广泛性焦虑症', '鉴别诊断@疾病', '社交性焦虑'), ('广泛性焦虑症', '鉴别诊断@疾病', '分离性焦虑')}
# pred_triples:  {('骨性关节炎', '病因@社会学', '结晶性关节病'), ('骨性关节炎', '病因@社会学', '创伤'), ('骨性关节炎', '发病部位@部位', '踝关节')}
# gold_triples:  {('骨性关节炎', '发病部位@部位', '关节'), ('骨性关节炎', '发病部位@部位', '踝关节'), ('骨性关节炎', '病因@社会学', '创伤'), ('骨性关节炎', '发病部位@部位', '腕关节'), ('骨性关节炎', '病因@社会学', '结晶性关节病')}
# pred_triples:  {('胆囊穿孔', '死亡率@流行病学', '30%')}
# gold_triples:  {('胆囊穿孔', '死亡率@流行病学', '30%')}
# pred_triples:  {('乙型肝炎', '预防@其他', '不献血'), ('乙型肝炎', '预防@其他', '不捐献器官或精液')}
# gold_triples:  {('乙型肝炎', '预防@其他', '不献血'), ('乙型肝炎', '预防@其他', '不捐献器官或精液')}
# pred_triples:  {('心绞痛', '药物治疗@药物', 'β受体阻滞剂')}
# gold_triples:  {('心绞痛', '药物治疗@药物', 'β受体阻滞剂')}
# pred_triples:  set()
# gold_triples:  {('感染性心内膜炎', '病因@社会学', '链球菌')}
# pred_triples:  {('稳定型缺血性心脏疾病', '药物治疗@药物', '高强度他汀类药物')}
# gold_triples:  {('稳定型缺血性心脏疾病', '药物治疗@药物', '高强度他汀类药物治疗')}
# pred_triples:  {('营养性巨幼细胞性贫血', '药物治疗@药物', '维生素Bl2治疗'), ('营养性巨幼细胞性贫血', '病因@社会学', '维生素B12'), ('营养性巨幼细胞性贫血', '同义词@疾病', 'nutritional megaloblastic anemia'), ('营养性巨幼细胞性贫血', '病因@社会学', '叶酸缺乏')}
# gold_triples:  {('营养性巨幼细胞性贫血', '病因@社会学', '维生素B12和（或）叶酸缺乏'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '维生素B12'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '叶酸'), ('营养性巨幼细胞性贫血', '同义词@疾病', 'nutritional megaloblastic anemia')}
# pred_triples:  set()
# gold_triples:  {('原发性高血压', '预防@其他', '适量的咖啡因摄入量')}
# correct_num: 4698, predict_num: 8603, gold_num: 10613
# precision: 0.5460885737533355, recall: 0.4426646565532795, f1_score: 0.4889675270113246
# [99/897],train loss is:0.102319
# [199/897],train loss is:0.101054
# [299/897],train loss is:0.101759
# [399/897],train loss is:0.101378
# [499/897],train loss is:0.100807
# [599/897],train loss is:0.101040
# [699/897],train loss is:0.101169
# [799/897],train loss is:0.101502
# epoch:[8],train loss is:0.101303
#
# pred_triples:  {('梗阻性胆总管结石', '影像学检查@检查', 'ERCP')}
# gold_triples:  {('急性胰腺炎', '影像学检查@检查', 'ERCP')}
# pred_triples:  set()
# gold_triples:  {('广泛性焦虑症', '鉴别诊断@疾病', '社交性焦虑'), ('广泛性焦虑症', '鉴别诊断@疾病', '分离性焦虑')}
# pred_triples:  {('骨性关节炎', '发病部位@部位', '踝关节'), ('骨性关节炎', '病因@社会学', '创伤'), ('骨性关节炎', '发病部位@部位', '腕关节'), ('骨性关节炎', '发病部位@部位', '关节炎@在其他关节（如踝关节'), ('骨性关节炎', '病因@社会学', '结晶性关节病')}
# gold_triples:  {('骨性关节炎', '发病部位@部位', '关节'), ('骨性关节炎', '发病部位@部位', '踝关节'), ('骨性关节炎', '病因@社会学', '创伤'), ('骨性关节炎', '发病部位@部位', '腕关节'), ('骨性关节炎', '病因@社会学', '结晶性关节病')}
# pred_triples:  {('胆囊炎', '死亡率@流行病学', '30%')}
# gold_triples:  {('胆囊穿孔', '死亡率@流行病学', '30%')}
# pred_triples:  {('乙型肝炎', '预防@其他', '使用漂白剂'), ('乙型肝炎', '预防@其他', '不献血'), ('乙型肝炎', '预防@其他', '不捐献器官或精液')}
# gold_triples:  {('乙型肝炎', '预防@其他', '不献血'), ('乙型肝炎', '预防@其他', '不捐献器官或精液')}
# pred_triples:  {('心绞痛', '药物治疗@药物', 'β受体阻滞剂'), ('心绞痛', '药物治疗@药物', '抗心绞痛药物')}
# gold_triples:  {('心绞痛', '药物治疗@药物', 'β受体阻滞剂')}
# pred_triples:  set()
# gold_triples:  {('感染性心内膜炎', '病因@社会学', '链球菌')}
# pred_triples:  set()
# gold_triples:  {('稳定型缺血性心脏疾病', '药物治疗@药物', '高强度他汀类药物治疗')}
# pred_triples:  {('营养性巨幼细胞性贫血', '病因@社会学', '维生素B12'), ('营养性巨幼细胞性贫血', '病因@社会学', '叶酸'), ('营养性巨幼细胞性贫血', '同义词@疾病', 'nutritional megaloblastic anemia'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '维生素Bl2')}
# gold_triples:  {('营养性巨幼细胞性贫血', '病因@社会学', '维生素B12和（或）叶酸缺乏'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '维生素B12'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '叶酸'), ('营养性巨幼细胞性贫血', '同义词@疾病', 'nutritional megaloblastic anemia')}
# pred_triples:  {('原发性高血压', '辅助治疗@其他治疗', '适量的咖啡因摄入量')}
# gold_triples:  {('原发性高血压', '预防@其他', '适量的咖啡因摄入量')}
# correct_num: 4854, predict_num: 8967, gold_num: 10613
# precision: 0.5413181666109006, recall: 0.4573636106661598, f1_score: 0.4958120530657722
# [99/897],train loss is:0.090617
# [199/897],train loss is:0.088816
# [299/897],train loss is:0.088785
# [399/897],train loss is:0.088555
# [499/897],train loss is:0.087366
# [599/897],train loss is:0.087785
# [699/897],train loss is:0.088197
# [799/897],train loss is:0.088338
# epoch:[9],train loss is:0.088704
#
# pred_triples:  {('梗阻性胆总管结石', '影像学检查@检查', 'ERCP')}
# gold_triples:  {('急性胰腺炎', '影像学检查@检查', 'ERCP')}
# pred_triples:  set()
# gold_triples:  {('广泛性焦虑症', '鉴别诊断@疾病', '社交性焦虑'), ('广泛性焦虑症', '鉴别诊断@疾病', '分离性焦虑')}
# pred_triples:  {('骨性关节炎', '发病部位@部位', '腕关节'), ('骨性关节炎', '发病部位@部位', '踝关节')}
# gold_triples:  {('骨性关节炎', '发病部位@部位', '关节'), ('骨性关节炎', '发病部位@部位', '踝关节'), ('骨性关节炎', '病因@社会学', '创伤'), ('骨性关节炎', '发病部位@部位', '腕关节'), ('骨性关节炎', '病因@社会学', '结晶性关节病')}
# pred_triples:  {('胆囊穿孔', '死亡率@流行病学', '30%'), ('胆囊炎', '死亡率@流行病学', '30%')}
# gold_triples:  {('胆囊穿孔', '死亡率@流行病学', '30%')}
# pred_triples:  {('乙型肝炎', '预防@其他', '使用漂白剂或洗涤剂清洁溢出血液，不献血'), ('乙型肝炎', '预防@其他', '不献血'), ('乙型肝炎', '预防@其他', '不捐献器官或精液')}
# gold_triples:  {('乙型肝炎', '预防@其他', '不献血'), ('乙型肝炎', '预防@其他', '不捐献器官或精液')}
# pred_triples:  set()
# gold_triples:  {('心绞痛', '药物治疗@药物', 'β受体阻滞剂')}
# pred_triples:  {('感染性心内膜炎', '病因@社会学', '葡萄球菌'), ('感染性心内膜炎', '病因@社会学', '链球菌')}
# gold_triples:  {('感染性心内膜炎', '病因@社会学', '链球菌')}
# pred_triples:  {('稳定型缺血性心脏疾病', '药物治疗@药物', '高强度他汀类药物治疗')}
# gold_triples:  {('稳定型缺血性心脏疾病', '药物治疗@药物', '高强度他汀类药物治疗')}
# pred_triples:  {('营养性巨幼细胞性贫血', '病因@社会学', '维生素B12和（或）叶酸缺乏'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '维生素Bl2治疗'), ('营养性巨幼细胞性贫血', '同义词@疾病', 'nutritional megaloblastic anemia')}
# gold_triples:  {('营养性巨幼细胞性贫血', '病因@社会学', '维生素B12和（或）叶酸缺乏'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '维生素B12'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '叶酸'), ('营养性巨幼细胞性贫血', '同义词@疾病', 'nutritional megaloblastic anemia')}
# pred_triples:  set()
# gold_triples:  {('原发性高血压', '预防@其他', '适量的咖啡因摄入量')}
# correct_num: 4536, predict_num: 7997, gold_num: 10613
# precision: 0.5672127047642795, recall: 0.42740035805144233, f1_score: 0.48747984949423906
# [99/897],train loss is:0.077638
# [199/897],train loss is:0.076752
# [299/897],train loss is:0.076927
# [399/897],train loss is:0.076696
# [499/897],train loss is:0.077731
# [599/897],train loss is:0.077617
# [699/897],train loss is:0.078343
# [799/897],train loss is:0.078826
# epoch:[10],train loss is:0.079621
#
# pred_triples:  {('梗阻性胆总管结石', '影像学检查@检查', 'ERCP'), ('急性胰腺炎', '影像学检查@检查', 'ERCP')}
# gold_triples:  {('急性胰腺炎', '影像学检查@检查', 'ERCP')}
# pred_triples:  set()
# gold_triples:  {('广泛性焦虑症', '鉴别诊断@疾病', '社交性焦虑'), ('广泛性焦虑症', '鉴别诊断@疾病', '分离性焦虑')}
# pred_triples:  {('骨性关节炎', '发病部位@部位', '关节'), ('骨性关节炎', '发病部位@部位', '踝关节'), ('骨性关节炎', '病因@社会学', '创伤'), ('骨性关节炎', '发病部位@部位', '腕关节'), ('骨性关节炎', '病因@社会学', '结晶性关节病')}
# gold_triples:  {('骨性关节炎', '发病部位@部位', '关节'), ('骨性关节炎', '发病部位@部位', '踝关节'), ('骨性关节炎', '病因@社会学', '创伤'), ('骨性关节炎', '发病部位@部位', '腕关节'), ('骨性关节炎', '病因@社会学', '结晶性关节病')}
# pred_triples:  {('胆囊炎', '死亡率@流行病学', '30%')}
# gold_triples:  {('胆囊穿孔', '死亡率@流行病学', '30%')}
# pred_triples:  {('乙型肝炎', '预防@其他', '不献血'), ('乙型肝炎', '预防@其他', '不捐献器官或精液')}
# gold_triples:  {('乙型肝炎', '预防@其他', '不献血'), ('乙型肝炎', '预防@其他', '不捐献器官或精液')}
# pred_triples:  {('心绞痛', '药物治疗@药物', 'β受体阻滞剂'), ('抗心绞痛', '药物治疗@药物', 'β受体阻滞剂'), ('抗心绞痛', '药物治疗@药物', '抗心绞痛药物 * 抗心绞痛药物的主要目标是减少心绞痛症状，改善生活质量。稳定型缺血性心脏疾病@ * β受体阻滞剂')}
# gold_triples:  {('心绞痛', '药物治疗@药物', 'β受体阻滞剂')}
# pred_triples:  {('感染性心内膜炎', '病因@社会学', '葡萄球菌'), ('感染性心内膜炎', '病因@社会学', '链球菌')}
# gold_triples:  {('感染性心内膜炎', '病因@社会学', '链球菌')}
# pred_triples:  {('稳定型缺血性心脏疾病', '药物治疗@药物', '高强度他汀类药物治疗')}
# gold_triples:  {('稳定型缺血性心脏疾病', '药物治疗@药物', '高强度他汀类药物治疗')}
# pred_triples:  {('营养性巨幼细胞性贫血', '药物治疗@药物', '维生素Bl2治疗'), ('营养性巨幼细胞性贫血', '病因@社会学', '维生素B12和（或）叶酸'), ('营养性巨幼细胞性贫血', '同义词@疾病', 'nutritional megaloblastic anemia')}
# gold_triples:  {('营养性巨幼细胞性贫血', '病因@社会学', '维生素B12和（或）叶酸缺乏'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '维生素B12'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '叶酸'), ('营养性巨幼细胞性贫血', '同义词@疾病', 'nutritional megaloblastic anemia')}
# pred_triples:  set()
# gold_triples:  {('原发性高血压', '预防@其他', '适量的咖啡因摄入量')}
# correct_num: 4804, predict_num: 8302, gold_num: 10613
# precision: 0.5786557456034621, recall: 0.452652407424852, f1_score: 0.5079566481135748
# [99/897],train loss is:0.066443
# [199/897],train loss is:0.065989
# [299/897],train loss is:0.066662
# [399/897],train loss is:0.067342
# [499/897],train loss is:0.068625
# [599/897],train loss is:0.068764
# [699/897],train loss is:0.068817
# [799/897],train loss is:0.068978
# epoch:[11],train loss is:0.069599
#
# pred_triples:  {('急性胰腺炎@有研究显示，进行早期 ERCP （24 小时内）可以降低梗阻性胆总管结石', '影像学检查@检查', 'ERCP'), ('胆汁性急性胰腺炎', '影像学检查@检查', 'ERCP'), ('梗阻性胆总管结石', '影像学检查@检查', 'ERCP')}
# gold_triples:  {('急性胰腺炎', '影像学检查@检查', 'ERCP')}
# pred_triples:  {('焦虑情绪', '临床表现@症状', '担忧过去的行为'), ('焦虑情绪', '临床表现@症状', '担忧将来的意外事件'), ('焦虑情绪', '临床表现@症状', '躯体不适症状'), ('焦虑情绪', '临床表现@症状', '担忧自己的能力')}
# gold_triples:  {('广泛性焦虑症', '鉴别诊断@疾病', '社交性焦虑'), ('广泛性焦虑症', '鉴别诊断@疾病', '分离性焦虑')}
# pred_triples:  {('骨性关节炎', '发病部位@部位', '关节'), ('骨性关节炎', '发病部位@部位', '踝关节'), ('骨性关节炎', '病因@社会学', '创伤'), ('骨性关节炎', '发病部位@部位', '腕关节'), ('骨性关节炎', '病因@社会学', '结晶性关节病')}
# gold_triples:  {('骨性关节炎', '发病部位@部位', '关节'), ('骨性关节炎', '发病部位@部位', '踝关节'), ('骨性关节炎', '病因@社会学', '创伤'), ('骨性关节炎', '发病部位@部位', '腕关节'), ('骨性关节炎', '病因@社会学', '结晶性关节病')}
# pred_triples:  {('胆囊穿孔', '死亡率@流行病学', '30%'), ('胆囊炎', '死亡率@流行病学', '30%')}
# gold_triples:  {('胆囊穿孔', '死亡率@流行病学', '30%')}
# pred_triples:  {('乙型肝炎', '预防@其他', '使用漂白剂或洗涤剂清洁溢出血液，不献血'), ('乙型肝炎', '预防@其他', '不献血'), ('乙型肝炎', '预防@其他', '不捐献器官或精液')}
# gold_triples:  {('乙型肝炎', '预防@其他', '不献血'), ('乙型肝炎', '预防@其他', '不捐献器官或精液')}
# pred_triples:  {('心绞痛', '药物治疗@药物', 'β受体阻滞剂'), ('心绞痛', '药物治疗@药物', '抗心绞痛药物'), ('稳定型缺血性心脏疾病', '药物治疗@药物', '抗心绞痛药物'), ('稳定型缺血性心脏疾病', '药物治疗@药物', 'β受体阻滞剂')}
# gold_triples:  {('心绞痛', '药物治疗@药物', 'β受体阻滞剂')}
# pred_triples:  {('感染性心内膜炎', '病因@社会学', '葡萄球菌'), ('感染性心内膜炎', '病因@社会学', '链球菌')}
# gold_triples:  {('感染性心内膜炎', '病因@社会学', '链球菌')}
# pred_triples:  {('稳定型缺血性心脏疾病', '药物治疗@药物', '高强度他汀类药物治疗')}
# gold_triples:  {('稳定型缺血性心脏疾病', '药物治疗@药物', '高强度他汀类药物治疗')}
# pred_triples:  {('营养性巨幼细胞性贫血', '病因@社会学', '维生素B12和（或）叶酸缺乏'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '维生素Bl2治疗'), ('营养性巨幼细胞性贫血', '同义词@疾病', 'nutritional megaloblastic anemia')}
# gold_triples:  {('营养性巨幼细胞性贫血', '病因@社会学', '维生素B12和（或）叶酸缺乏'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '维生素B12'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '叶酸'), ('营养性巨幼细胞性贫血', '同义词@疾病', 'nutritional megaloblastic anemia')}
# pred_triples:  {('原发性高血压', '辅助治疗@其他治疗', '适量的咖啡因摄入量')}
# gold_triples:  {('原发性高血压', '预防@其他', '适量的咖啡因摄入量')}
# correct_num: 5370, predict_num: 10784, gold_num: 10613
# precision: 0.49795994065281435, recall: 0.5059832281164561, f1_score: 0.5019395241823674
# [99/897],train loss is:0.067188
# [199/897],train loss is:0.063996
# [299/897],train loss is:0.061540
# [399/897],train loss is:0.061552
# [499/897],train loss is:0.061155
# [599/897],train loss is:0.061734
# [699/897],train loss is:0.062039
# [799/897],train loss is:0.062506
# epoch:[12],train loss is:0.062822
#
# pred_triples:  {('梗阻性胆总管结石', '影像学检查@检查', 'ERCP'), ('胆汁性急性胰腺炎', '影像学检查@检查', 'ERCP')}
# gold_triples:  {('急性胰腺炎', '影像学检查@检查', 'ERCP')}
# pred_triples:  {('焦虑', '临床表现@症状', '自我意识'), ('焦虑', '临床表现@症状', '担忧自己的能力'), ('焦虑', '临床表现@症状', '躯体不适症状'), ('焦虑', '临床表现@症状', '担忧将来的意外事件'), ('焦虑', '临床表现@症状', '担忧过去的行为')}
# gold_triples:  {('广泛性焦虑症', '鉴别诊断@疾病', '社交性焦虑'), ('广泛性焦虑症', '鉴别诊断@疾病', '分离性焦虑')}
# pred_triples:  {('骨性关节炎', '发病部位@部位', '关节'), ('骨性关节炎', '发病部位@部位', '踝关节'), ('骨性关节炎', '病因@社会学', '创伤'), ('骨性关节炎', '发病部位@部位', '腕关节'), ('骨性关节炎', '病因@社会学', '结晶性关节病')}
# gold_triples:  {('骨性关节炎', '发病部位@部位', '关节'), ('骨性关节炎', '发病部位@部位', '踝关节'), ('骨性关节炎', '病因@社会学', '创伤'), ('骨性关节炎', '发病部位@部位', '腕关节'), ('骨性关节炎', '病因@社会学', '结晶性关节病')}
# pred_triples:  {('胆囊穿孔', '死亡率@流行病学', '30%'), ('胆囊炎', '死亡率@流行病学', '30%')}
# gold_triples:  {('胆囊穿孔', '死亡率@流行病学', '30%')}
# pred_triples:  {('乙型肝炎', '预防@其他', '不献血'), ('乙型肝炎', '预防@其他', '不捐献器官或精液')}
# gold_triples:  {('乙型肝炎', '预防@其他', '不献血'), ('乙型肝炎', '预防@其他', '不捐献器官或精液')}
# pred_triples:  set()
# gold_triples:  {('心绞痛', '药物治疗@药物', 'β受体阻滞剂')}
# pred_triples:  {('感染性心内膜炎', '病因@社会学', '葡萄球菌'), ('感染性心内膜炎', '病因@社会学', '链球菌')}
# gold_triples:  {('感染性心内膜炎', '病因@社会学', '链球菌')}
# pred_triples:  set()
# gold_triples:  {('稳定型缺血性心脏疾病', '药物治疗@药物', '高强度他汀类药物治疗')}
# pred_triples:  {('营养性巨幼细胞性贫血', '药物治疗@药物', '维生素Bl2治疗'), ('营养性巨幼细胞性贫血', '病因@社会学', '维生素B12和（或）叶酸'), ('营养性巨幼细胞性贫血', '同义词@疾病', 'nutritional megaloblastic anemia'), ('营养性巨幼细胞性贫血', '病因@社会学', '叶酸')}
# gold_triples:  {('营养性巨幼细胞性贫血', '病因@社会学', '维生素B12和（或）叶酸缺乏'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '维生素B12'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '叶酸'), ('营养性巨幼细胞性贫血', '同义词@疾病', 'nutritional megaloblastic anemia')}
# pred_triples:  {('原发性高血压', '辅助治疗@其他治疗', '适量的咖啡因摄入量'), ('原发性高血压', '辅助治疗@其他治疗', '咖啡因摄入量')}
# gold_triples:  {('原发性高血压', '预防@其他', '适量的咖啡因摄入量')}
# correct_num: 4975, predict_num: 9250, gold_num: 10613
# precision: 0.537837837837832, recall: 0.4687647225101247, f1_score: 0.5009313799029061
# [99/897],train loss is:0.054170
# [199/897],train loss is:0.053571
# [299/897],train loss is:0.055067
# [399/897],train loss is:0.056145
# [499/897],train loss is:0.056478
# [599/897],train loss is:0.056849
# [699/897],train loss is:0.056619
# [799/897],train loss is:0.057156
# epoch:[13],train loss is:0.056929
#
# pred_triples:  {('梗阻性胆总管结石', '影像学检查@检查', 'ERCP'), ('胆汁性急性胰腺炎', '影像学检查@检查', 'ERCP')}
# gold_triples:  {('急性胰腺炎', '影像学检查@检查', 'ERCP')}
# pred_triples:  {('焦虑', '临床表现@症状', '自我意识'), ('焦虑', '临床表现@症状', '担忧自己的能力'), ('焦虑', '临床表现@症状', '躯体不适症状'), ('焦虑', '临床表现@症状', '担忧将来的意外事件'), ('焦虑', '临床表现@症状', '担忧过去的行为')}
# gold_triples:  {('广泛性焦虑症', '鉴别诊断@疾病', '社交性焦虑'), ('广泛性焦虑症', '鉴别诊断@疾病', '分离性焦虑')}
# pred_triples:  {('骨性关节炎', '发病部位@部位', '踝关节'), ('骨性关节炎', '病因@社会学', '创伤'), ('骨性关节炎', '发病部位@部位', '腕关节'), ('骨性关节炎', '发病部位@部位', '关节炎@在其他关节（如踝关节'), ('骨性关节炎', '病因@社会学', '结晶性关节病')}
# gold_triples:  {('骨性关节炎', '发病部位@部位', '关节'), ('骨性关节炎', '发病部位@部位', '踝关节'), ('骨性关节炎', '病因@社会学', '创伤'), ('骨性关节炎', '发病部位@部位', '腕关节'), ('骨性关节炎', '病因@社会学', '结晶性关节病')}
# pred_triples:  {('胆囊炎', '死亡率@流行病学', '30%')}
# gold_triples:  {('胆囊穿孔', '死亡率@流行病学', '30%')}
# pred_triples:  {('乙型肝炎', '预防@其他', '不献血'), ('乙型肝炎', '预防@其他', '不捐献器官或精液')}
# gold_triples:  {('乙型肝炎', '预防@其他', '不献血'), ('乙型肝炎', '预防@其他', '不捐献器官或精液')}
# pred_triples:  {('抗心绞痛', '药物治疗@药物', 'β受体阻滞剂'), ('抗心绞痛', '药物治疗@药物', '抗心绞痛药物 * 抗心绞痛药物的主要目标是减少心绞痛症状，改善生活质量。稳定型缺血性心脏疾病@ * β受体阻滞剂')}
# gold_triples:  {('心绞痛', '药物治疗@药物', 'β受体阻滞剂')}
# pred_triples:  {('感染性心内膜炎', '病因@社会学', '葡萄球菌'), ('感染性心内膜炎', '病因@社会学', '链球菌')}
# gold_triples:  {('感染性心内膜炎', '病因@社会学', '链球菌')}
# pred_triples:  {('稳定型缺血性心脏疾病', '药物治疗@药物', '高强度他汀类药物治疗')}
# gold_triples:  {('稳定型缺血性心脏疾病', '药物治疗@药物', '高强度他汀类药物治疗')}
# pred_triples:  {('nutritional megaloblastic anemia', '病因@社会学', '维生素B12和（或）叶酸缺乏'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '维生素Bl2'), ('营养性巨幼细胞性贫血', '同义词@疾病', 'nutritional megaloblastic anemia'), ('营养性巨幼细胞性贫血', '病因@社会学', '维生素B12和（或）叶酸缺乏'), ('nutritional megaloblastic anemia', '药物治疗@药物', '维生素Bl2治疗'), ('nutritional megaloblastic anemia', '同义词@疾病', 'nutritional megaloblastic anemia')}
# gold_triples:  {('营养性巨幼细胞性贫血', '病因@社会学', '维生素B12和（或）叶酸缺乏'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '维生素B12'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '叶酸'), ('营养性巨幼细胞性贫血', '同义词@疾病', 'nutritional megaloblastic anemia')}
# pred_triples:  {('原发性高血压', '辅助治疗@其他治疗', '适量的咖啡因摄入量')}
# gold_triples:  {('原发性高血压', '预防@其他', '适量的咖啡因摄入量')}
# correct_num: 5242, predict_num: 9590, gold_num: 10613
# precision: 0.5466110531803905, recall: 0.49392254781870826, f1_score: 0.5189328317077827
# [99/897],train loss is:0.048820
# [199/897],train loss is:0.048794
# [299/897],train loss is:0.050013
# [399/897],train loss is:0.049265
# [499/897],train loss is:0.049134
# [599/897],train loss is:0.050565
# [699/897],train loss is:0.051257
# [799/897],train loss is:0.051187
# epoch:[14],train loss is:0.051470
#
# pred_triples:  {('梗阻性胆总管结石', '影像学检查@检查', 'ERCP')}
# gold_triples:  {('急性胰腺炎', '影像学检查@检查', 'ERCP')}
# pred_triples:  set()
# gold_triples:  {('广泛性焦虑症', '鉴别诊断@疾病', '社交性焦虑'), ('广泛性焦虑症', '鉴别诊断@疾病', '分离性焦虑')}
# pred_triples:  {('骨性关节炎', '发病部位@部位', '关节'), ('骨性关节炎', '病因@社会学', '创伤'), ('骨性关节炎', '发病部位@部位', '腕关节'), ('骨性关节炎', '发病部位@部位', '踝关节')}
# gold_triples:  {('骨性关节炎', '发病部位@部位', '关节'), ('骨性关节炎', '发病部位@部位', '踝关节'), ('骨性关节炎', '病因@社会学', '创伤'), ('骨性关节炎', '发病部位@部位', '腕关节'), ('骨性关节炎', '病因@社会学', '结晶性关节病')}
# pred_triples:  {('胆囊穿孔', '死亡率@流行病学', '30%'), ('胆囊炎', '死亡率@流行病学', '30%')}
# gold_triples:  {('胆囊穿孔', '死亡率@流行病学', '30%')}
# pred_triples:  {('乙型肝炎', '预防@其他', '不献血'), ('乙型肝炎', '预防@其他', '不捐献器官或精液')}
# gold_triples:  {('乙型肝炎', '预防@其他', '不献血'), ('乙型肝炎', '预防@其他', '不捐献器官或精液')}
# pred_triples:  set()
# gold_triples:  {('心绞痛', '药物治疗@药物', 'β受体阻滞剂')}
# pred_triples:  {('感染性心内膜炎', '病因@社会学', '葡萄球菌'), ('感染性心内膜炎', '病因@社会学', '链球菌')}
# gold_triples:  {('感染性心内膜炎', '病因@社会学', '链球菌')}
# pred_triples:  {('稳定型缺血性心脏疾病', '药物治疗@药物', '高强度他汀类药物治疗')}
# gold_triples:  {('稳定型缺血性心脏疾病', '药物治疗@药物', '高强度他汀类药物治疗')}
# pred_triples:  {('营养性巨幼细胞性贫血', '病因@社会学', '维生素B12和（或）叶酸缺乏'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '维生素Bl2'), ('营养性巨幼细胞性贫血', '同义词@疾病', 'nutritional megaloblastic anemia')}
# gold_triples:  {('营养性巨幼细胞性贫血', '病因@社会学', '维生素B12和（或）叶酸缺乏'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '维生素B12'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '叶酸'), ('营养性巨幼细胞性贫血', '同义词@疾病', 'nutritional megaloblastic anemia')}
# pred_triples:  {('原发性高血压', '辅助治疗@其他治疗', '适量的咖啡因摄入量')}
# gold_triples:  {('原发性高血压', '预防@其他', '适量的咖啡因摄入量')}
# correct_num: 5122, predict_num: 9182, gold_num: 10613
# precision: 0.5578305380091423, recall: 0.48261566003956957, f1_score: 0.5175044202584148
# [99/897],train loss is:0.046003
# [199/897],train loss is:0.045745
# [299/897],train loss is:0.045848
# [399/897],train loss is:0.045973
# [499/897],train loss is:0.046196
# [599/897],train loss is:0.046768
# [699/897],train loss is:0.047538
# [799/897],train loss is:0.047722
# epoch:[15],train loss is:0.048192
#
# pred_triples:  set()
# gold_triples:  {('急性胰腺炎', '影像学检查@检查', 'ERCP')}
# pred_triples:  {('焦虑情绪', '临床表现@症状', '担忧过去的行为'), ('焦虑情绪', '临床表现@症状', '担忧将来的意外事件'), ('焦虑情绪', '临床表现@症状', '躯体不适'), ('焦虑情绪', '临床表现@症状', '担忧自己的能力')}
# gold_triples:  {('广泛性焦虑症', '鉴别诊断@疾病', '社交性焦虑'), ('广泛性焦虑症', '鉴别诊断@疾病', '分离性焦虑')}
# pred_triples:  {('骨性关节炎', '发病部位@部位', '关节'), ('骨性关节炎', '发病部位@部位', '踝关节'), ('骨性关节炎', '病因@社会学', '创伤'), ('骨性关节炎', '发病部位@部位', '腕关节'), ('骨性关节炎', '病因@社会学', '结晶性关节病')}
# gold_triples:  {('骨性关节炎', '发病部位@部位', '关节'), ('骨性关节炎', '发病部位@部位', '踝关节'), ('骨性关节炎', '病因@社会学', '创伤'), ('骨性关节炎', '发病部位@部位', '腕关节'), ('骨性关节炎', '病因@社会学', '结晶性关节病')}
# pred_triples:  {('胆囊炎', '死亡率@流行病学', '30%')}
# gold_triples:  {('胆囊穿孔', '死亡率@流行病学', '30%')}
# pred_triples:  {('乙型肝炎', '预防@其他', '不献血'), ('乙型肝炎', '预防@其他', '不捐献器官或精液')}
# gold_triples:  {('乙型肝炎', '预防@其他', '不献血'), ('乙型肝炎', '预防@其他', '不捐献器官或精液')}
# pred_triples:  {('稳定型缺血性心脏疾病', '药物治疗@药物', '抗心绞痛药物'), ('稳定型缺血性心脏疾病', '药物治疗@药物', 'β受体阻滞剂')}
# gold_triples:  {('心绞痛', '药物治疗@药物', 'β受体阻滞剂')}
# pred_triples:  {('感染性心内膜炎', '病因@社会学', '葡萄球菌'), ('感染性心内膜炎', '病因@社会学', '链球菌')}
# gold_triples:  {('感染性心内膜炎', '病因@社会学', '链球菌')}
# pred_triples:  {('稳定型缺血性心脏疾病', '药物治疗@药物', '高强度他汀类药物治疗')}
# gold_triples:  {('稳定型缺血性心脏疾病', '药物治疗@药物', '高强度他汀类药物治疗')}
# pred_triples:  {('营养性巨幼细胞性贫血', '病因@社会学', '维生素B12和（或）叶酸缺乏'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '维生素Bl2'), ('营养性巨幼细胞性贫血', '同义词@疾病', 'nutritional megaloblastic anemia')}
# gold_triples:  {('营养性巨幼细胞性贫血', '病因@社会学', '维生素B12和（或）叶酸缺乏'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '维生素B12'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '叶酸'), ('营养性巨幼细胞性贫血', '同义词@疾病', 'nutritional megaloblastic anemia')}
# pred_triples:  {('原发性高血压', '辅助治疗@其他治疗', '适量的咖啡因摄入量')}
# gold_triples:  {('原发性高血压', '预防@其他', '适量的咖啡因摄入量')}
# correct_num: 5045, predict_num: 9003, gold_num: 10613
# precision: 0.5603687659668937, recall: 0.47536040704795557, f1_score: 0.5143760195261879
# [99/897],train loss is:0.041714
# [199/897],train loss is:0.042008
# [299/897],train loss is:0.042427
# [399/897],train loss is:0.042941
# [499/897],train loss is:0.043352
# [599/897],train loss is:0.044073
# [699/897],train loss is:0.044270
# [799/897],train loss is:0.044347
# epoch:[16],train loss is:0.044603
#
# pred_triples:  {('梗阻性胆总管结石', '影像学检查@检查', 'ERCP')}
# gold_triples:  {('急性胰腺炎', '影像学检查@检查', 'ERCP')}
# pred_triples:  {('焦虑情绪', '临床表现@症状', '担忧过去的行为'), ('焦虑情绪', '临床表现@症状', '担忧将来的意外事件'), ('焦虑情绪', '临床表现@症状', '躯体不适症状'), ('焦虑情绪', '临床表现@症状', '担忧自己的能力')}
# gold_triples:  {('广泛性焦虑症', '鉴别诊断@疾病', '社交性焦虑'), ('广泛性焦虑症', '鉴别诊断@疾病', '分离性焦虑')}
# pred_triples:  {('骨性关节炎', '发病部位@部位', '关节'), ('骨性关节炎', '发病部位@部位', '踝关节'), ('骨性关节炎', '病因@社会学', '创伤'), ('骨性关节炎', '发病部位@部位', '腕关节'), ('骨性关节炎', '病因@社会学', '结晶性关节病')}
# gold_triples:  {('骨性关节炎', '发病部位@部位', '关节'), ('骨性关节炎', '发病部位@部位', '踝关节'), ('骨性关节炎', '病因@社会学', '创伤'), ('骨性关节炎', '发病部位@部位', '腕关节'), ('骨性关节炎', '病因@社会学', '结晶性关节病')}
# pred_triples:  {('胆囊穿孔', '死亡率@流行病学', '30%'), ('胆囊炎', '死亡率@流行病学', '30%')}
# gold_triples:  {('胆囊穿孔', '死亡率@流行病学', '30%')}
# pred_triples:  {('乙型肝炎', '预防@其他', '不献血'), ('乙型肝炎', '预防@其他', '不捐献器官或精液')}
# gold_triples:  {('乙型肝炎', '预防@其他', '不献血'), ('乙型肝炎', '预防@其他', '不捐献器官或精液')}
# pred_triples:  {('稳定型缺血性心脏疾病', '药物治疗@药物', '抗心绞痛药物'), ('稳定型缺血性心脏疾病', '药物治疗@药物', 'β受体阻滞剂')}
# gold_triples:  {('心绞痛', '药物治疗@药物', 'β受体阻滞剂')}
# pred_triples:  {('感染性心内膜炎', '病因@社会学', '葡萄球菌'), ('感染性心内膜炎', '病因@社会学', '链球菌')}
# gold_triples:  {('感染性心内膜炎', '病因@社会学', '链球菌')}
# pred_triples:  {('稳定型缺血性心脏疾病', '药物治疗@药物', '高强度他汀类药物治疗')}
# gold_triples:  {('稳定型缺血性心脏疾病', '药物治疗@药物', '高强度他汀类药物治疗')}
# pred_triples:  {('营养性巨幼细胞性贫血', '药物治疗@药物', '维生素Bl2'), ('营养性巨幼细胞性贫血', '同义词@疾病', 'nutritional megaloblastic anemia'), ('nutritional megaloblastic anemia', '药物治疗@药物', '维生素Bl2'), ('营养性巨幼细胞性贫血', '病因@社会学', '维生素B12和（或）叶酸缺乏'), ('nutritional megaloblastic anemia', '同义词@疾病', 'nutritional megaloblastic anemia')}
# gold_triples:  {('营养性巨幼细胞性贫血', '病因@社会学', '维生素B12和（或）叶酸缺乏'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '维生素B12'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '叶酸'), ('营养性巨幼细胞性贫血', '同义词@疾病', 'nutritional megaloblastic anemia')}
# pred_triples:  {('原发性高血压', '辅助治疗@其他治疗', '适量的咖啡因摄入量')}
# gold_triples:  {('原发性高血压', '预防@其他', '适量的咖啡因摄入量')}
# correct_num: 5415, predict_num: 10073, gold_num: 10613
# precision: 0.5375756974089095, recall: 0.5102233110336332, f1_score: 0.5235424924570385
# [99/897],train loss is:0.043164
# [199/897],train loss is:0.041394
# [299/897],train loss is:0.040516
# [399/897],train loss is:0.040548
# [499/897],train loss is:0.041541
# [599/897],train loss is:0.041645
# [699/897],train loss is:0.041965
# [799/897],train loss is:0.041651
# epoch:[17],train loss is:0.041792
#
# pred_triples:  {('梗阻性胆总管结石', '影像学检查@检查', 'ERCP'), ('胆汁性急性胰腺炎', '影像学检查@检查', 'ERCP')}
# gold_triples:  {('急性胰腺炎', '影像学检查@检查', 'ERCP')}
# pred_triples:  {('焦虑', '临床表现@症状', '躯体不适症状')}
# gold_triples:  {('广泛性焦虑症', '鉴别诊断@疾病', '社交性焦虑'), ('广泛性焦虑症', '鉴别诊断@疾病', '分离性焦虑')}
# pred_triples:  {('骨性关节炎', '发病部位@部位', '关节'), ('骨性关节炎', '发病部位@部位', '踝关节'), ('骨性关节炎', '病因@社会学', '创伤'), ('骨性关节炎', '发病部位@部位', '腕关节'), ('骨性关节炎', '病因@社会学', '结晶性关节病')}
# gold_triples:  {('骨性关节炎', '发病部位@部位', '关节'), ('骨性关节炎', '发病部位@部位', '踝关节'), ('骨性关节炎', '病因@社会学', '创伤'), ('骨性关节炎', '发病部位@部位', '腕关节'), ('骨性关节炎', '病因@社会学', '结晶性关节病')}
# pred_triples:  {('胆囊炎', '死亡率@流行病学', '30%')}
# gold_triples:  {('胆囊穿孔', '死亡率@流行病学', '30%')}
# pred_triples:  {('乙型肝炎', '预防@其他', '不献血'), ('乙型肝炎', '预防@其他', '不捐献器官或精液')}
# gold_triples:  {('乙型肝炎', '预防@其他', '不献血'), ('乙型肝炎', '预防@其他', '不捐献器官或精液')}
# pred_triples:  {('心肌梗死', '药物治疗@药物', 'β受体阻滞剂'), ('心绞痛', '药物治疗@药物', 'β受体阻滞剂')}
# gold_triples:  {('心绞痛', '药物治疗@药物', 'β受体阻滞剂')}
# pred_triples:  {('感染性心内膜炎', '病因@社会学', '葡萄球菌'), ('感染性心内膜炎', '病因@社会学', '链球菌')}
# gold_triples:  {('感染性心内膜炎', '病因@社会学', '链球菌')}
# pred_triples:  {('稳定型缺血性心脏疾病', '药物治疗@药物', '高强度他汀类药物治疗')}
# gold_triples:  {('稳定型缺血性心脏疾病', '药物治疗@药物', '高强度他汀类药物治疗')}
# pred_triples:  {('营养性巨幼细胞性贫血', '病因@社会学', '维生素B12和（或）叶酸缺乏'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '维生素Bl2'), ('营养性巨幼细胞性贫血', '同义词@疾病', 'nutritional megaloblastic anemia')}
# gold_triples:  {('营养性巨幼细胞性贫血', '病因@社会学', '维生素B12和（或）叶酸缺乏'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '维生素B12'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '叶酸'), ('营养性巨幼细胞性贫血', '同义词@疾病', 'nutritional megaloblastic anemia')}
# pred_triples:  {('原发性高血压', '辅助治疗@其他治疗', '适量的咖啡因摄入量')}
# gold_triples:  {('原发性高血压', '预防@其他', '适量的咖啡因摄入量')}
# correct_num: 5284, predict_num: 9509, gold_num: 10613
# precision: 0.5556840887580129, recall: 0.49787995854140676, f1_score: 0.5251963025045634
# [99/897],train loss is:0.031814
# [199/897],train loss is:0.034828
# [299/897],train loss is:0.036303
# [399/897],train loss is:0.035919
# [499/897],train loss is:0.037244
# [599/897],train loss is:0.037039
# [699/897],train loss is:0.036890
# [799/897],train loss is:0.036648
# epoch:[18],train loss is:0.036869
#
# pred_triples:  {('梗阻性胆总管结石', '影像学检查@检查', 'ERCP')}
# gold_triples:  {('急性胰腺炎', '影像学检查@检查', 'ERCP')}
# pred_triples:  set()
# gold_triples:  {('广泛性焦虑症', '鉴别诊断@疾病', '社交性焦虑'), ('广泛性焦虑症', '鉴别诊断@疾病', '分离性焦虑')}
# pred_triples:  {('骨性关节炎', '发病部位@部位', '关节'), ('骨性关节炎', '病因@社会学', '创伤'), ('骨性关节炎', '发病部位@部位', '腕关节'), ('骨性关节炎', '发病部位@部位', '踝关节')}
# gold_triples:  {('骨性关节炎', '发病部位@部位', '关节'), ('骨性关节炎', '发病部位@部位', '踝关节'), ('骨性关节炎', '病因@社会学', '创伤'), ('骨性关节炎', '发病部位@部位', '腕关节'), ('骨性关节炎', '病因@社会学', '结晶性关节病')}
# pred_triples:  {('胆囊穿孔', '死亡率@流行病学', '30%')}
# gold_triples:  {('胆囊穿孔', '死亡率@流行病学', '30%')}
# pred_triples:  {('乙型肝炎', '预防@其他', '不献血'), ('乙型肝炎', '预防@其他', '不捐献器官或精液')}
# gold_triples:  {('乙型肝炎', '预防@其他', '不献血'), ('乙型肝炎', '预防@其他', '不捐献器官或精液')}
# pred_triples:  set()
# gold_triples:  {('心绞痛', '药物治疗@药物', 'β受体阻滞剂')}
# pred_triples:  {('感染性心内膜炎', '病因@社会学', '葡萄球菌'), ('感染性心内膜炎', '病因@社会学', '链球菌')}
# gold_triples:  {('感染性心内膜炎', '病因@社会学', '链球菌')}
# pred_triples:  set()
# gold_triples:  {('稳定型缺血性心脏疾病', '药物治疗@药物', '高强度他汀类药物治疗')}
# pred_triples:  {('营养性巨幼细胞性贫血', '病因@社会学', '维生素B12和（或）叶酸缺乏'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '维生素B12'), ('营养性巨幼细胞性贫血', '同义词@疾病', 'nutritional megaloblastic anemia'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '维生素Bl2')}
# gold_triples:  {('营养性巨幼细胞性贫血', '病因@社会学', '维生素B12和（或）叶酸缺乏'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '维生素B12'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '叶酸'), ('营养性巨幼细胞性贫血', '同义词@疾病', 'nutritional megaloblastic anemia')}
# pred_triples:  {('原发性高血压', '辅助治疗@其他治疗', '适量的咖啡因摄入量')}
# gold_triples:  {('原发性高血压', '预防@其他', '适量的咖啡因摄入量')}
# correct_num: 5194, predict_num: 9261, gold_num: 10613
# precision: 0.5608465608465548, recall: 0.48939979270705275, f1_score: 0.5226929656340341
# [99/897],train loss is:0.031398
# [199/897],train loss is:0.033194
# [299/897],train loss is:0.033209
# [399/897],train loss is:0.033746
# [499/897],train loss is:0.033811
# [599/897],train loss is:0.033730
# [699/897],train loss is:0.033644
# [799/897],train loss is:0.034217
# epoch:[19],train loss is:0.034416
#
# pred_triples:  set()
# gold_triples:  {('急性胰腺炎', '影像学检查@检查', 'ERCP')}
# pred_triples:  {('焦虑', '临床表现@症状', '躯体不适症状'), ('焦虑', '临床表现@症状', '担忧过去的行为； 4.躯体不适症状'), ('焦虑', '临床表现@症状', '担忧将来的意外事件')}
# gold_triples:  {('广泛性焦虑症', '鉴别诊断@疾病', '社交性焦虑'), ('广泛性焦虑症', '鉴别诊断@疾病', '分离性焦虑')}
# pred_triples:  {('骨性关节炎', '发病部位@部位', '关节'), ('骨性关节炎', '发病部位@部位', '踝关节'), ('骨性关节炎', '病因@社会学', '创伤'), ('骨性关节炎', '发病部位@部位', '腕关节'), ('骨性关节炎', '病因@社会学', '结晶性关节病')}
# gold_triples:  {('骨性关节炎', '发病部位@部位', '关节'), ('骨性关节炎', '发病部位@部位', '踝关节'), ('骨性关节炎', '病因@社会学', '创伤'), ('骨性关节炎', '发病部位@部位', '腕关节'), ('骨性关节炎', '病因@社会学', '结晶性关节病')}
# pred_triples:  {('胆囊炎', '死亡率@流行病学', '30%')}
# gold_triples:  {('胆囊穿孔', '死亡率@流行病学', '30%')}
# pred_triples:  {('乙型肝炎', '预防@其他', '不献血'), ('乙型肝炎', '预防@其他', '不捐献器官或精液')}
# gold_triples:  {('乙型肝炎', '预防@其他', '不献血'), ('乙型肝炎', '预防@其他', '不捐献器官或精液')}
# pred_triples:  {('心绞痛', '药物治疗@药物', 'β受体阻滞剂')}
# gold_triples:  {('心绞痛', '药物治疗@药物', 'β受体阻滞剂')}
# pred_triples:  {('感染性心内膜炎', '病因@社会学', '葡萄球菌'), ('感染性心内膜炎', '病理分型@疾病', '真菌性感染性心内膜炎'), ('感染性心内膜炎', '病因@社会学', '链球菌')}
# gold_triples:  {('感染性心内膜炎', '病因@社会学', '链球菌')}
# pred_triples:  set()
# gold_triples:  {('稳定型缺血性心脏疾病', '药物治疗@药物', '高强度他汀类药物治疗')}
# pred_triples:  {('营养性巨幼细胞性贫血', '病因@社会学', '维生素B12和（或）叶酸缺乏'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '维生素B12'), ('营养性巨幼细胞性贫血', '同义词@疾病', 'nutritional megaloblastic anemia'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '维生素Bl2')}
# gold_triples:  {('营养性巨幼细胞性贫血', '病因@社会学', '维生素B12和（或）叶酸缺乏'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '维生素B12'), ('营养性巨幼细胞性贫血', '药物治疗@药物', '叶酸'), ('营养性巨幼细胞性贫血', '同义词@疾病', 'nutritional megaloblastic anemia')}
# pred_triples:  {('原发性高血压', '辅助治疗@其他治疗', '适量的咖啡因摄入量')}
# gold_triples:  {('原发性高血压', '预防@其他', '适量的咖啡因摄入量')}
# correct_num: 5326, predict_num: 9398, gold_num: 10613
# precision: 0.5667163226218284, recall: 0.5018373692641053, f1_score: 0.5323072309731164

# %% [markdown]
# <br>
#
# ### 四、模型预测

# %%
from tqdm import tqdm
from ark_nlp.model.re.casrel_bert import Predictor

casrel_re_predictor_instance = Predictor(model.module, tokenizer, re_train_dataset.cat2id)

# %%
test_data_path = '../mydata/data_origin/220602_0902-cblue-nlp-医疗nlp打榜/CMeIE/CMeIE_test.jsonl'
schemas_data_path = '../mydata/data_origin/220602_0902-cblue-nlp-医疗nlp打榜/CMeIE/53_schemas.jsonl'
output_data_path = './CMeIE_test.jsonl'

# %%
result = []

with open(test_data_path, 'r', encoding='utf-8') as f:
    lines = f.readlines()
    for line_ in lines:
        result.append(casrel_re_predictor_instance.predict_one_sample(eval(line_)['text']))

# %%
all_subject_type = []
all_predicate = []
all_shcemas = []
predicate2subject = {}
with open(schemas_data_path, 'r', encoding='utf-8') as fs:
    for jsonstr in fs.readlines():
        jsonstr = json.loads(jsonstr)
        # all_shcemas.append(jsonstr)
        
        predicate2subject[jsonstr['predicate']+'@'+jsonstr['object_type']] = jsonstr['subject_type']
        
    fs.close()
    
all_predicate = set(all_predicate)
with open(output_data_path, 'w', encoding='utf-8') as fw:
    with open(test_data_path, 'r', encoding='utf-8') as f:
        lines = f.readlines()
        for index_, jsonstr in tqdm(enumerate(lines)):
            line = json.loads(jsonstr)
            results_len = []
            sentence = line['text']
            dict_list = result[index_]
            new = []
            for list_ in dict_list:
                for predicate_ in predicate2subject:
                    if list_[1] == predicate_:
                        if list_[-1] != '' and list_[-1] != '[UNK]':
                            result_dict = {
                                'predicate': predicate_.split('@')[0],
                                "subject": list_[0],
                                'subject_type': predicate2subject[predicate_],
                                "object": {"@value": list_[-1]},
                                'object_type': {"@value":predicate_.split('@')[-1]}
                                }
                        else:
                            continue
                        if result_dict not in new:
                            new.append(result_dict)
            if sum([item.count('。') for item in sentence]) >= 2:
                for item in new:
                    item['Combined'] = True
            else:
                for item in new:
                    item['Combined'] = False

            if len(new) == 0:
                new = [{
                    "Combined": '',
                    "predicate": '',
                    "subject": '',
                    "subject_type": '',
                    "object": {"@value": ""},
                    "object_type": {"@value": ""},
                }]
                pred_dict = {
                    "text": ''.join(sentence),
                    "spo_list": new,
                }
            else:

                pred_dict = {
                    "text": ''.join(sentence),
                    "spo_list": new,
                }
            fw.write(json.dumps(pred_dict, ensure_ascii=False) + '\n')
f.close()
fw.close()
# Out:
# 4482it [00:00, 18378.52it/s]
